# %% [markdown]
# **Task#1**

# %%
l1=["apple","banana","cherry","kiwi","mango"]
l2=input("Enter a String To Search: ")
if l2 in l1:
  print("Found")
else:
  print("Not Found")
# Out:
# Enter a String To Search: banana
# Found

# %% [markdown]
# **Task#2**

# %%
d1={
    "a":1,
    "b":2,
    "c":3,
    "d":4,
    "e":5
    }
d2={}
for k,v in d1.items():
  d2[v]=k
print(d2)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd', 5: 'e'}

# %% [markdown]
# **Task#3**

# %%
a=int(input("Enter a Number to print its table: "))
for i in range(1,11):
  print(f"{a} x {i} = {a*i}")
# Out:
# Enter a Number to print its table: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# **Task#4**

# %%
person1={
    "name":"Tom",
    "age":25,
    "city":"New York",
    "color":['red','blue','green'],
}
s1=input("Enter your favourite color: ")
person1["color"].append(s1)
person1["age"]=person1["age"]+1
print(person1)
# Out:
# Enter your favourite color: green
# {'name': 'Tom', 'age': 26, 'city': 'New York', 'color': ['red', 'blue', 'green', 'green']}

# %% [markdown]
# **Task#5**

# %%
a1=int(input("Enter a Starting Number: "))
while True:
  a2=int(input("Enter a Dividing Number (-1 to exit): "))
  if(a2>a1):
    print("Dividing Number should be less than Starting Number")
    continue
  a1=a1/a2
  if(a1<1 or a2==-1):
    break
  print("New Value: ",a1)
# Out:
# Enter a Starting Number: 100
# Enter a Dividing Number (-1 to exit): 20
# New Value:  5.0
# Enter a Dividing Number (-1 to exit): 4
# New Value:  1.25
# Enter a Dividing Number (-1 to exit): 2
# Dividing Number should be less than Starting Number
# Enter a Dividing Number (-1 to exit): -1

# %% [markdown]
# **Task#6**

# %%
person = [
    {"first_name": "Wade", "last_name": "Wilson"},
    {"first_name": "Shawn", "last_name": "Levy"},
    {"first_name": "Wade", "last_name": "Wilson"},
    {"first_name": "Rocky", "last_name": "Johnson"},
    {"first_name": "Michael", "last_name": "Jordan"},
    {"first_name": "Rocky", "last_name": "Johnson"},
    {"first_name": "Wade", "last_name": "Wilson"},
]

f_names = {}

for person in person:
    f_name = person["first_name"] + " " + person["last_name"]
    f_names[f_name] = f_names.get(f_name, 0) + 1

print(f_names)
# Out:
# {'Wade Wilson': 3, 'Shawn Levy': 1, 'Rocky Johnson': 2, 'Michael Jordan': 1}

# %% [markdown]
# **Task#7**

# %%
numbers = [23, 11, 46, 18, 25, 34, 67, 90, 13, 52]

even_num = []
odd_num = []

for num in numbers:
    if num % 2 == 0:
        even_num.append(num)
    else:
        odd_num.append(num)

print("Even numbers:", even_num)
print("Odd numbers:", odd_num)
# Out:
# Even numbers: [46, 18, 34, 90, 52]
# Odd numbers: [23, 11, 25, 67, 13]

# %% [markdown]
# **Task#8**

# %%
prices = {
    "apple": 250,
    "banana": 200,
    "orange": 180,
    "milk": 220,
    "eggs": 300
}
while True:
    item_name = input("Enter an item name (or 'stop' to quit): ")
    if item_name == "stop":
        print("Exiting the program.")
        break
    if item_name in prices:
        print(f"The price of {item_name} is Rs.{prices[item_name]}")
    else:
        print(f"Not found: {item_name}")
# Out:
# Enter an item name (or 'stop' to quit): bread
# Not found: bread
# Enter an item name (or 'stop' to quit): eggs
# The price of eggs is Rs.300
# Enter an item name (or 'stop' to quit): orange
# The price of orange is Rs.180
# Enter an item name (or 'stop' to quit): stop
# Exiting the program.

# %% [markdown]
# **Task#9**

# %%
a1=input("Enter the Number or 'exit' to Finish: ")
while True:
  a2=input("Enter the Number or 'exit' to Finish: ")
  if a2=="exit":
    print("The Total is:",a1)
    break
  else:
    a1=int(a1)+int(a2)
    print("New Value:",a1)
# Out:
# Enter the Number or 'exit' to Finish: 200
# Enter the Number or 'exit' to Finish: 490
# New Value: 690
# Enter the Number or 'exit' to Finish: 560
# New Value: 1250
# Enter the Number or 'exit' to Finish: 380
# New Value: 1630
# Enter the Number or 'exit' to Finish: 290
# New Value: 1920
# Enter the Number or 'exit' to Finish: 530
# New Value: 2450
# Enter the Number or 'exit' to Finish: exit
# The Total is: 2450

# %% [markdown]
# **Task#10**

# %%
activities = {
    "Monday": ["Work", "Gym"],
    "Tuesday": ["Study", "Relax"],
    "Wednesday": ["Work", "Meet friends"],
    "Thursday": ["Study", "Watch movie"],
    "Friday": ["Work", "Party"],
    "Saturday": ["Relax", "Outdoor activities"],
    "Sunday": ["Relax", "Watch movie"]
}
day = input("Enter a day of the week: ")
if day.capitalize() in activities:
    print("Activities for", day, ":", activities[day.capitalize()])
else:
    print("Invalid day")
# Out:
# Enter a day of the week: Thursday
# Activities for Thursday : ['Study', 'Watch movie']
